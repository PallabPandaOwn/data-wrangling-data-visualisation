# %%
#import Pandas
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"D:\Personal\Udemy-Training\complete-data-wrangling-data-visualisation-with-python\Data-and-Code\Data and Code\section4\Indicators.csv")
data.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5656458 entries, 0 to 5656457
# Data columns (total 6 columns):
# CountryName      object
# CountryCode      object
# IndicatorName    object
# IndicatorCode    object
# Year             int64
# Value            float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 258.9+ MB

# %%
data.describe() # stattistical summary of quantitative(other than categorical data) data
# Out:
#                Year         Value
# count  5.656458e+06  5.656458e+06
# mean   1.994464e+03  1.070501e+12
# std    1.387895e+01  4.842469e+13
# min    1.960000e+03 -9.824821e+15
# 25%    1.984000e+03  5.566242e+00
# 50%    1.997000e+03  6.357450e+01
# 75%    2.006000e+03  1.346722e+07
# max    2.015000e+03  1.103367e+16

# %%
data.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# IndicatorName    0
# IndicatorCode    0
# Year             0
# Value            0
# dtype: int64

# %%
data.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# IndicatorName    0
# IndicatorCode    0
# Year             0
# Value            0
# dtype: int64

# %%
data.columns #Dispaly columns
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', 'Year',
#        'Value'],
#       dtype='object')

# %%
list(data) #display columns
# Out:
# ['CountryName',
#  'CountryCode',
#  'IndicatorName',
#  'IndicatorCode',
#  'Year',
#  'Value']

# %%
data.dtypes
# Out:
# CountryName       object
# CountryCode       object
# IndicatorName     object
# IndicatorCode     object
# Year               int64
# Value            float64
# dtype: object

# %%
data['Year'].dtypes
# Out:
# dtype('int64')

# %%
len(data['CountryName'])
# Out:
# 5656458

# %%
len(data['CountryName'].unique())
# Out:
# 247

# %%
data['CountryName'].unique().tolist()
# Out:
# ['Arab World',
#  'Caribbean small states',
#  'Central Europe and the Baltics',
#  'East Asia & Pacific (all income levels)',
#  'East Asia & Pacific (developing only)',
#  'Euro area',
#  'Europe & Central Asia (all income levels)',
#  'Europe & Central Asia (developing only)',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income: nonOECD',
#  'High income: OECD',
#  'Latin America & Caribbean (all income levels)',
#  'Latin America & Caribbean (developing only)',
#  'Least developed countries: UN classification',
#  'Low & middle income',
#  'Low income',
#  'Lower middle income',
#  'Middle East & North Africa (all income levels)',
#  'Middle East & North Africa (developing only)',
#  'Middle income',
#  'North America',
#  'OECD members',
#  'Other small states',
#  'Pacific island small states',
#  'Small states',
#  'South Asia',
#  'Sub-Saharan Africa (all income levels)',
# ...

# %%
from collections import Counter
c = Counter(data['CountryName'])
c
# Out:
# Counter({'Afghanistan': 17402,
#          'Albania': 23164,
#          'Algeria': 34578,
#          'American Samoa': 2802,
#          'Andorra': 4921,
#          'Angola': 21158,
#          'Antigua and Barbuda': 13851,
#          'Arab World': 17115,
#          'Argentina': 25955,
#          'Armenia': 20992,
#          'Aruba': 7607,
#          'Australia': 25325,
#          'Austria': 25516,
#          'Azerbaijan': 21165,
#          'Bahamas, The': 18165,
#          'Bahrain': 17278,
#          'Bangladesh': 33386,
#          'Barbados': 17611,
#          'Belarus': 21875,
#          'Belgium': 23461,
#          'Belize': 29689,
#          'Benin': 32965,
#          'Bermuda': 8765,
#          'Bhutan': 23395,
#          'Bolivia': 35307,
#          'Bosnia and Herzegovina': 16514,
#          'Botswana': 32039,
#          'Brazil': 35550,
#          'Brunei Darussalam': 16965,
#          'Bulgaria': 29859,
#          'Burkina Faso': 32604,
#          'Burundi': 30494,
# ...

# %%
# Data handling by conditional statements

# %%
data1 = pd.read_csv(r"D:\Personal\Udemy-Training\complete-data-wrangling-data-visualisation-with-python\Data-and-Code\Data and Code\section4\endangeredLang.csv")
data1.head()
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
# ...

# %%
data1.Countries
# Out:
# 0                                                   Italy
# 1                                                   Italy
# 2       Germany, Denmark, Netherlands, Poland, Russian...
# 3       Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                      Italy, Switzerland
# 5       Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                  Israel
# 7                                                   India
# 8                           Germany, Belgium, Netherlands
# 9                        Bolivia (Plurinational State of)
# 10                                           India, Nepal
# 11          Bolivia (Plurinational State of), Chile, Peru
# 12                                      Italy, San Marino
# 13                                                  Italy
# 14                               Croatia, Italy, Slovenia
# 15                                                 Turkey
# ...

# %%
data1[['Countries','Name in English']]
# Out:
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# 7                                                 India
# 8                         Germany, Belgium, Netherlands
# 9                      Bolivia (Plurinational State of)
# 10                                         India, Nepal
# 11        Bolivia (Plurinational State of), Chile, Peru
# 12                                    Italy, San Marino
# 13                                                Italy
# 14                             Croatia, Italy, Slovenia
# 15                                               Turkey
# ...

# %%
data1.shape
#data1[3:10,1:3]
# Out:
# (2722, 9)

# %%
data1.iloc[3:10,1:3]
# Out:
#                Name in English  \
# 3                   Belarusian
# 4                      Lombard
# 5                       Romani
# 6             Yiddish (Israel)
# 7                        Gondi
# 8         Limburgian-Ripuarian
# 9  Quechua of Southern Bolivia
#
#                                            Countries
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# 9                   Bolivia (Plurinational State of)

# %%
data1.columns
# Out:
# Index(['ID', 'Name in English', 'Countries', 'Country codes alpha 3',
#        'Degree of endangerment', 'Number of speakers', 'Latitude', 'Longitude',
#        'Description of the location'],
#       dtype='object')

# %%
data1[data1['Number of speakers'] >40000]
# Out:
#        ID              Name in English  \
# 0    1022                South Italian
# 1    1023                     Sicilian
# 2     383                    Low Saxon
# 3     335                   Belarusian
# 4     382                      Lombard
# 5     405                       Romani
# 6    2211             Yiddish (Israel)
# 7    1586                        Gondi
# 8    1020         Limburgian-Ripuarian
# 9    1943  Quechua of Southern Bolivia
# 10   1565                      Kumaoni
# 11    755                       Aymara
# 12    349             Emilian-Romagnol
# 13    399                  Piedmontese
# 14   1021                      Venetan
# 15   1985                       Zazaki
# 16   1591                Kurux (India)
# 17   2065                      Tamajeq
# 18   1585                         Tulu
# 19   1556                       Kangdi
# 20    410                        Scots
# 21   1026                       Torlak
# 22   1476                 West Flemish
# ...

# %%
#dropcColumn/ Row

# %%
data1[data1['Countries']=='India']
# Out:
#         ID   Name in English Countries Country codes alpha 3  \
# 7     1586             Gondi     India                   IND
# 16    1591     Kurux (India)     India                   IND
# 18    1585              Tulu     India                   IND
# 19    1556            Kangdi     India                   IND
# 26    1227           Meithei     India                   IND
# 33    1577               Kui     India                   IND
# 34    1231             Khasi     India                   IND
# 35    1229              Bodo     India                   IND
# 44    1211           Mundari     India                   IND
# 52    1559          Mandeali     India                   IND
# 56    1091            Mising     India                   IND
# 58    1230              Mizo     India                   IND
# 64    1558           Mahasui     India                   IND
# 72    1165             Karbi     India                   IND
# ...

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.drop(data1.iloc[:,:1],axis=1)
# Out:
#                                  Name in English  \
# 0                                  South Italian
# 1                                       Sicilian
# 2                                      Low Saxon
# 3                                     Belarusian
# 4                                        Lombard
# 5                                         Romani
# 6                               Yiddish (Israel)
# 7                                          Gondi
# 8                           Limburgian-Ripuarian
# 9                    Quechua of Southern Bolivia
# 10                                       Kumaoni
# 11                                        Aymara
# 12                              Emilian-Romagnol
# 13                                   Piedmontese
# 14                                       Venetan
# 15                                        Zazaki
# 16                                 Kurux (India)
# 17                                       Tamajeq
# ...

# %%
#change the column name

# %%
data2 = pd.read_csv(r"D:\Personal\Udemy-Training\complete-data-wrangling-data-visualisation-with-python\Data-and-Code\Data and Code\section4\StudentsPerformance.csv")
data2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#new_cols = ['Race','Education','Tution']
data2.rename(columns={'race/ethnicity':'Race','parental level of education':'Education','test preparation course':'Tution'}).head()
#data2.head()
# Out:
#    gender     Race           Education         lunch     Tution  math score  \
# 0  female  group B   bachelor's degree      standard       none          72
# 1  female  group C        some college      standard  completed          69
# 2  female  group B     master's degree      standard       none          90
# 3    male  group A  associate's degree  free/reduced       none          47
# 4    male  group C        some college      standard       none          76
#
#    reading score  writing score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75

# %%
#changing the data types of column

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data2['math score'].head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
data2['math score'].astype(float).head()
# Out:
# 0    72.0
# 1    69.0
# 2    90.0
# 3    47.0
# 4    76.0
# Name: math score, dtype: float64

# %%
# DateTime data exploration and visualization

# %%
data3 = pd.read_csv(r"D:\Personal\Udemy-Training\complete-data-wrangling-data-visualisation-with-python\Data-and-Code\Data and Code\section4\all_stocks_5yr.csv")
data3.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 619040 entries, 0 to 619039
# Data columns (total 7 columns):
# date      619040 non-null object
# open      619029 non-null float64
# high      619032 non-null float64
# low       619032 non-null float64
# close     619040 non-null float64
# volume    619040 non-null int64
# Name      619040 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 33.1+ MB

# %%
import datetime as dt
data3['date']=data3['date'].apply(pd.to_datetime)
data3['date'].describe()
# Out:
# count                  619040
# unique                   1259
# top       2018-01-09 00:00:00
# freq                      505
# first     2013-02-08 00:00:00
# last      2018-02-07 00:00:00
# Name: date, dtype: object

# %%
data3.sort_values(by='date')
# Out:
#              date     open      high       low    close    volume   Name
# 0      2013-02-08   15.070   15.1200   14.6300   14.750   8407500    AAL
# 508224 2013-02-08   81.220   81.9300   80.9400   81.890    296853    SLG
# 506965 2013-02-08   78.240   79.0700   78.1250   79.070   4632684    SLB
# 85755  2013-02-08  236.640  238.6924  235.7500  238.160    552207    BLK
# 505706 2013-02-08   89.040   89.4800   88.9100   89.160    554948    SJM
# 87014  2013-02-08   22.635   22.7600   22.5875   22.680   1242144    BLL
# 504447 2013-02-08   63.170   63.5100   62.5500   62.910    723691    SIG
# 88273  2013-02-08   36.500   37.0300   36.4900   37.030   8462351    BMY
# 503188 2013-02-08  163.140  164.0000  162.6800  163.770    379624    SHW
# 501929 2013-02-08   19.240   19.3000   19.0900   19.250   1331904    SEE
# 89530  2013-02-08   97.250   97.3300   96.7300   97.250   2996000  BRK.B
# 500670 2013-02-08   17.180   17.2300   16.8100   16.890  15136075   SCHW
# ...

# %%
data3['date'].min()
# Out:
# Timestamp('2013-02-08 00:00:00')
